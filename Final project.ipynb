# %%
print('Final Project: Improving health through reducing sedentary screen time')
# Out:
# Final Project: Improving health through reducing sedentary screen time

# %%
import matplotlib.pyplot as plt

# Convert hours + minutes into decimal hours
us_average = 7 + 2/60        # 7 hours 2 minutes
world_average = 6 + 54/60    # 6 hours 54 minutes
negative_threshold = 2       # 2 hours recreational screen time


print("What are your screen habits?")
print("If you have a smartphone, access your average daily screen time through your device settings.")

phone_screen_time = float(input("Enter your daily smartphone screen time average in hours: "))

# Bar graph comparing user to averages
labels = ["Your Phone Use", "U.S. Average", "Worldwide Average"]
values = [phone_screen_time, us_average, world_average]

plt.bar(labels, values, color=['blue','red','green'])
plt.ylabel("Hours per day")
plt.title("Daily Screen Time Comparison")
plt.show()


print("\nScreen time for recreation is appealing to many because it can feel relaxing.")
print("However, too much recreational screen time may be linked to negative health outcomes.")

guess = float(input("How many hours of recreational screen time per day do you think is the threshold for negative health outcomes? "))

if guess == negative_threshold:
    print("Precisely!")
elif guess < negative_threshold:
    print("Not quite — the threshold is a little higher.")
else:
    print("It is actually less than that.")

print("The threshold is about 2 hours per day.")
print("\nFurthermore:")
print("If excessive recreational screen time threshold is regularly exceeded, being physically active may not fully offset the negative health effects.")

print("\nScreen time is also unavoidable in many settings, such as work or school.")
non_leisure_screen_time = float(input("How many hours of unavoidable non-leisure screen time do you spend per day? "))


recreational_screen_time = ask_float("Enter your average daily recreational TV, video game, computer, and/or tablet screen time in hours (do not include smartphone): ")

total_screen_time = phone_screen_time + non_leisure_screen_time + recreational_screen_time

print(f"\nYour estimated total daily screen time is {total_screen_time:.2f} hours.")
print("Note: Total screen time is an approximation.")

# Second graph
labels = ["Phone Leisure\nScreen Time", "Other Leisure\nScreen Time", "Unavoidable\nScreen Time", "Total\nScreen Time"]
values = [phone_screen_time, recreational_screen_time, non_leisure_screen_time, total_screen_time]

plt.bar(labels, values, color=['cyan','magenta','yellow','red'])
plt.ylabel("Hours per day")
plt.title("Your Estimated Daily Screen Time")
plt.show()
# Out:
# What are your screen habits?
# If you have a smartphone, access your average daily screen time through your device settings.
# Enter your daily smartphone screen time average in hours:  10
# Screen time for recreation is appealing to many because it can feel relaxing.
# However, too much recreational screen time may be linked to negative health outcomes.
# How many hours of recreational screen time per day do you think is the threshold for negative health outcomes?  5
# It is actually less than that.
# The threshold is about 2 hours per day.
#
# Furthermore:
# If excessive recreational screen time threshold is regularly exceeded, being physically active may not fully offset the negative health effects.
#
# Screen time is also unavoidable in many settings, such as work or school.
# How many hours of unavoidable non-leisure screen time do you spend per day?  15
# Enter your average daily recreational TV, video game, computer, and/or tablet screen time in hours (do not include smartphone):  20
# Your estimated total daily screen time is 45.00 hours.
# Note: Total screen time is an approximation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit


#creating functions 

def ask_float(prompt):
    """asking user to input a number. repeats until valid input is typed in"""
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("Please enter a number (e.g., 3.5)")


def ask_yes_no(prompt):
    """true for yes, false for no"""
    while True:
        answer = input(prompt + " ").lower().strip()
        if answer in ["yes", "y"]:
            return True
        elif answer in ["no", "n"]:
            return False
        else:
            print("Please enter yes or no.")


def show_bar_graph(labels, values, title, ylabel="Hours per day"):
    """Create a simple bar graph."""
    plt.figure(figsize=(8, 5))
    plt.bar(labels, values)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()


def print_table(data, title):
    """Print a pandas table with a title."""
    print("\n" + title)
    print("-" * len(title))
    df = pd.DataFrame(data)
    print(df.to_string(index=False))
    return df


#symptom checklist 

symptoms = [
    "difficulty sleeping",
    "anxiety",
    "depression",
    "eye strain or headaches",
    "neck, shoulder, or back pain",
    "difficulty focusing"
]

symptom_results = []

print("\nWhich of the following have you experienced after high-screen-time days?")

for symptom in symptoms:
    experienced = ask_yes_no(f"Have you experienced {symptom}? yes/no:")
    symptom_results.append({
        "Symptom": symptom,
        "User Experiences This?": "Yes" if experienced else "No"
    })

symptom_df = print_table(symptom_results, "Your Symptom Checklist")

number_of_symptoms = sum(row["User Experiences This?"] == "Yes" for row in symptom_results)

if number_of_symptoms == 0:
    print("\nWow, that's great! You may not be noticing obvious side effects right now.")
else:
    print("\nYou're not alone!")
    print("Excessive sedentary screen time has been associated with sleep problems, mental health challenges, eye strain, headaches, and body pain.")


# -----------------------------
# Section 3: Motivation / Continue Logic
# -----------------------------

print("\nSo... do you want to proceed and learn how to improve your quality of life and reduce these symptoms?")

wants_to_continue = ask_yes_no("Enter yes or no:")

if wants_to_continue:
    print("\nGreat :) let's continue!")
else:
    print("\nEven if you live an otherwise healthy, active lifestyle, excessive passive screen time may still affect long-term health.")
    print("Research suggests that physical activity may not fully erase the negative effects of high sedentary TV/screen time.")

    wants_to_continue = ask_yes_no("\nWhat about now? Do you want to learn how to make your life easier and healthier? yes/no:")

    if wants_to_continue:
        print("\nGreat :) let's continue!")
    else:
        print("\nOkay, that's fine.")
        print("Outside of screens, are there any habits you wish to change or begin?")
        print("The same behavior-change principles can apply to many habits.")

        print("\n1. No, my life is already perfect and I do not want to change anything.")
        print("2. I want to learn more.")

        choice = input("Enter 1 or 2: ").strip()

        if choice == "2":
            print("\nGreat :) let's continue!")
        else:
            print("\nOkay, well I guess you can stop reading this now...")
            print("But this is literally my research project, so it would be kind of boring if you ended it here.")

            print("\n1. Continue and learn")
            print("2. Stop program here")

            choice = input("Enter 1 or 2: ").strip()

            if choice == "1":
                print("\nGreat :) Let's continue!")
            else:
                print("\nProgram terminated.")
                raise SystemExit

print("\nDo you already incorporate any of the following screen-time reduction strategies?")
print("Type yes or no for each option.\n")

strategies = [
    "use app time limits",
    "disable non-essential notifications",
    "have a screen-free time of day, such as before bed",
    "keep your phone out of reach while studying or working",
]

used_strategies = []

for strategy in strategies:
    answer = input(f"Do you use {strategy}? ").lower()

    if answer == "yes":
        used_strategies.append(strategy)

print("\nYou currently use", len(used_strategies), "screen-time reduction strategies.")

if len(used_strategies) == 0:
    print("That's okay — this gives you a clear starting point.")
elif len(used_strategies) <= 2:
    print("Nice start! There is still room to add a few more supports.")
else:
    print("Great job — you already have several helpful strategies in place.")
# -----------------------------
# Section 4: Strategy Checklist
# -----------------------------

strategy_categories = {
    "Movement During Unavoidable Screen Time": [
        "standing desk",
        "walking pad",
        "under-desk pedal device",
        "taking movement breaks during work/school screen time"
    ],
    "Increasing Friction Against Recreational Screen Use": [
        "app time limits",
        "disabling non-essential notifications",
        "deleting or hiding distracting apps",
        "keeping phone away from bed",
        "creating screen-free zones"
    ],
    "Decreasing Friction for Physical Activity": [
        "placing workout equipment in visible areas",
        "watching TV only while walking/stretching",
        "using VR fitness or active video games",
        "planning non-screen hobbies in advance"
    ]
}

strategy_results = []
category_scores = {}

print("\nAre you interested in any of the following screen-time reduction strategies?")

for category, strategies in strategy_categories.items():
    print(f"\nCategory: {category}")
    used_count = 0

    for strategy in strategies:
        uses_strategy = ask_yes_no(f"Would you use this strategy: {strategy}? yes/no:")

        if uses_strategy:
            used_count += 1

        strategy_results.append({
            "Category": category,
            "Strategy": strategy,
            "Interested?": "Yes" if uses_strategy else "No"
        })

    category_scores[category] = used_count

print("\nSummary")

strategy_df = print_table(strategy_results, "Your Screen Time Strategy Checklist")


def show_donut_chart(labels, data, title):
    
    # Prevent errors if no strategies selected
    if sum(data) == 0:
        print("No strategies were selected, so no donut chart can be displayed.")
        return

    colors = ['#6BAED6', '#74C476', '#FDAE6B']

    # Slight "pop out" effect
    explode = [0.05]*len(data)

    plt.figure(figsize=(8,8))

    plt.pie(
        data,
        labels=labels,
        colors=colors,
        explode=explode,
        autopct='%1.1f%%',
        pctdistance=0.82
    )

    # Create donut hole
    centre_circle = plt.Circle((0,0),0.65,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)

    plt.title(title)
    plt.tight_layout()
    plt.show()

# -----------------------------
# Section 5: Personalized Recommendations
# -----------------------------

recommendations = []

for category, strategies in strategy_categories.items():
    used_in_category = category_scores[category]
    total_in_category = len(strategies)

    if used_in_category == 0:
        recommendation = "High priority: consider implementing at least one strategy from this category."
    elif used_in_category < total_in_category / 2:
        recommendation = "Moderate priority: you have selected some strategies, but could add more support."
    else:
        recommendation = "Strong area: you have selected several strategies here."

    recommendations.append({
        "Intervention Category": category,
        "Strategies": f"{used_in_category}/{total_in_category}",
    })

recommendation_df = print_table(recommendations, "Personalized Intervention Recommendations")

# -----------------------------
# Section 8: Final Summary
# -----------------------------

print("\nSummary")

strategy_df = print_table(strategy_results, "Your Screen Time Strategy Checklist")

show_donut_chart(
    list(category_scores.keys()),
    list(category_scores.values()),
    "Distribution of Screen-Time Strategies You're Interested In"
)

print("-------------")
print(f"Estimated total daily screen time: {total_screen_time:.2f} hours")
print(f"Estimated recreational screen time: {recreational_screen_time:.2f} hours")
print(f"Number of strategies of interest: {sum(category_scores.values())}")

print("\nYour strongest strategy category:")

strongest_category = max(category_scores, key=category_scores.get)
weakest_category = min(category_scores, key=category_scores.get)

print(f"Strongest: {strongest_category}")
print(f"Needs most improvement: {weakest_category}")

print("\nMain takeaway:")
print("The most effective approach is usually not one single strategy category.")
print("A stronger plan combines movement during unavoidable screen time, more friction against recreational screen use,")
print("and easier access to physical activity or active alternatives.")
# Out:
# Which of the following have you experienced after high-screen-time days?
# Have you experienced difficulty sleeping? yes/no:  yes
# Have you experienced anxiety? yes/no:  yes
# Have you experienced depression? yes/no:  yes
# Have you experienced eye strain or headaches? yes/no:  no
# Have you experienced neck, shoulder, or back pain? yes/no:  no
# Have you experienced difficulty focusing? yes/no:  no
# Your Symptom Checklist
# ----------------------
#                      Symptom User Experiences This?
#          difficulty sleeping                    Yes
#                      anxiety                    Yes
#                   depression                    Yes
#      eye strain or headaches                     No
# neck, shoulder, or back pain                     No
#          difficulty focusing                     No
#
# You're not alone!
# Excessive sedentary screen time has been associated with sleep problems, mental health challenges, eye strain, headaches, and body pain.
#
# So... do you want to proceed and learn how to improve your quality of life and reduce these symptoms?
# Enter yes or no:  yes
# Great :) let's continue!
#
# Do you already incorporate any of the following screen-time reduction strategies?
# Type yes or no for each option.
# Do you use use app time limits?  yes
# Do you use disable non-essential notifications?  yes
# Do you use have a screen-free time of day, such as before bed?  no
# Do you use keep your phone out of reach while studying or working?  yes
# You currently use 3 screen-time reduction strategies.
# Great job — you already have several helpful strategies in place.
#
# Are you interested in any of the following screen-time reduction strategies?
#
# Category: Movement During Unavoidable Screen Time
# Would you use this strategy: standing desk? yes/no:  no
# Would you use this strategy: walking pad? yes/no:  no
# Would you use this strategy: under-desk pedal device? yes/no:  yes
# Would you use this strategy: taking movement breaks during work/school screen time? yes/no:  no
# Category: Increasing Friction Against Recreational Screen Use
# Would you use this strategy: app time limits? yes/no:  tes
# Please enter yes or no.
# Would you use this strategy: app time limits? yes/no:  yes
# Would you use this strategy: disabling non-essential notifications? yes/no:  yes
# Would you use this strategy: deleting or hiding distracting apps? yes/no:  no
# Would you use this strategy: keeping phone away from bed? yes/no:  yes
# Would you use this strategy: creating screen-free zones? yes/no:  no
# Category: Decreasing Friction for Physical Activity
# Would you use this strategy: placing workout equipment in visible areas? yes/no:  yes
# Would you use this strategy: watching TV only while walking/stretching? yes/no:  no
# Would you use this strategy: using VR fitness or active video games? yes/no:  yes
# Would you use this strategy: planning non-screen hobbies in advance? yes/no:  yes
# Summary
#
# Your Screen Time Strategy Checklist
# -----------------------------------
#                                            Category                                              Strategy Interested?
#             Movement During Unavoidable Screen Time                                         standing desk          No
#             Movement During Unavoidable Screen Time                                           walking pad          No
#             Movement During Unavoidable Screen Time                               under-desk pedal device         Yes
#             Movement During Unavoidable Screen Time taking movement breaks during work/school screen time          No
# Increasing Friction Against Recreational Screen Use                                       app time limits         Yes
# Increasing Friction Against Recreational Screen Use                 disabling non-essential notifications         Yes
# Increasing Friction Against Recreational Screen Use                   deleting or hiding distracting apps          No
# Increasing Friction Against Recreational Screen Use                           keeping phone away from bed         Yes
# Increasing Friction Against Recreational Screen Use                            creating screen-free zones          No
#           Decreasing Friction for Physical Activity            placing workout equipment in visible areas         Yes
#           Decreasing Friction for Physical Activity             watching TV only while walking/stretching          No
#           Decreasing Friction for Physical Activity                using VR fitness or active video games         Yes
#           Decreasing Friction for Physical Activity                planning non-screen hobbies in advance         Yes
#
# Personalized Intervention Recommendations
# -----------------------------------------
#                               Intervention Category Strategies
#             Movement During Unavoidable Screen Time        1/4
# Increasing Friction Against Recreational Screen Use        3/5
#           Decreasing Friction for Physical Activity        3/4
#
# Summary
#
# Your Screen Time Strategy Checklist
# -----------------------------------
#                                            Category                                              Strategy Interested?
#             Movement During Unavoidable Screen Time                                         standing desk          No
#             Movement During Unavoidable Screen Time                                           walking pad          No
#             Movement During Unavoidable Screen Time                               under-desk pedal device         Yes
#             Movement During Unavoidable Screen Time taking movement breaks during work/school screen time          No
# Increasing Friction Against Recreational Screen Use                                       app time limits         Yes
# Increasing Friction Against Recreational Screen Use                 disabling non-essential notifications         Yes
# Increasing Friction Against Recreational Screen Use                   deleting or hiding distracting apps          No
# Increasing Friction Against Recreational Screen Use                           keeping phone away from bed         Yes
# Increasing Friction Against Recreational Screen Use                            creating screen-free zones          No
#           Decreasing Friction for Physical Activity            placing workout equipment in visible areas         Yes
#           Decreasing Friction for Physical Activity             watching TV only while walking/stretching          No
#           Decreasing Friction for Physical Activity                using VR fitness or active video games         Yes
#           Decreasing Friction for Physical Activity                planning non-screen hobbies in advance         Yes
# -------------
# Estimated total daily screen time: 45.00 hours
# Estimated recreational screen time: 20.00 hours
# Number of strategies of interest: 7
#
# Your strongest strategy category:
# Strongest: Increasing Friction Against Recreational Screen Use
# Needs most improvement: Movement During Unavoidable Screen Time
#
# Main takeaway:
# The most effective approach is usually not one single strategy.
# A stronger plan combines movement during unavoidable screen time, more friction against recreational screen use,
# and easier access to physical activity or active alternatives.
